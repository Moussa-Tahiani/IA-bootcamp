# %% [markdown]
# <a href="https://colab.research.google.com/github/Moussa-Tahiani/ia-bootcamp/blob/main/Semaine1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, IA bootcamp - Semaine 1")
# Out:
# Hello, IA bootcamp - Semaine 1
